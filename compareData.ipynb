# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/marie-louise/Documents/sites/JupyterNotebooks/PublicationScripts'

# %%
os.listdir(os.getcwd())
# Out:
# ['versicolor.csv',
#  'Excel_diff.xlsx',
#  '.DS_Store',
#  'merge_csv.ipynb',
#  'setosa.csv',
#  'compareData.ipynb',
#  '.gitignore',
#  'returns-datasets-sep-2020.xlsx',
#  '.ipynb_checkpoints',
#  'test_merge.csv',
#  '.git',
#  '.idea']

# %%
df1 = pd.read_csv('setosa.csv')

# %%
df1
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df2 = pd.read_csv('versicolor.csv')

# %%
df2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           7.0          3.2           4.7          1.4  versicolor
# 1           6.4          3.2           4.5          1.5  versicolor
# 2           6.9          3.1           4.9          1.5  versicolor

# %%
df1.equals(df_2)
# Out:
# False

# %%
comparison_values = df1.values == df2.values

# %%
comparison_values
# Out:
# array([[False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False]])

# %%
rows,cols=np.where(comparison_values==False)

# %%
for item in zip(rows,cols):
    df1.iloc[item[0], item[1]] = '{} --> {}'.format(df1.iloc[item[0], item[1]],df2.iloc[item[0], item[1]])

# %%
df1.to_excel('./Excel_diff.xlsx',index=False,header=True)

# %% [markdown]
# ## Pivot

# %%
df_D01 = pd.read_excel (r'returns-datasets-sep-2020.xlsx', sheet_name='Data - Ret_D01')

# %%
df_D01.columns
# Out:
# Index(['Year', 'Quarter', 'Nationality', 'Region', 'Return type group',
#        'Return type', 'Age', 'Sex', 'Return destination group',
#        'Number of returns'],
#       dtype='object')

# %%
df_D01.head(3)
# Out:
#    Year  Quarter  Nationality        Region Return type group  \
# 0  2004  2004 Q1  Afghanistan  Asia Central   Enforced return
# 1  2004  2004 Q1  Afghanistan  Asia Central   Enforced return
# 2  2004  2004 Q1  Afghanistan  Asia Central   Enforced return
#
#          Return type       Age   Sex Return destination group  \
# 0  Enforced removals  Under 18  Male          EU Member State
# 1  Enforced removals  Under 18  Male            Other country
# 2  Enforced removals     18-29  Male          EU Member State
#
#    Number of returns
# 0                  6
# 1                  1
# 2                 39

# %%
df_D01['Quarter'][210895:]
# Out:
# 210895    2020 Q2
# 210896    2020 Q2
# 210897    2020 Q2
# 210898    2020 Q2
# 210899    2020 Q2
# 210900    2020 Q2
# 210901    2020 Q2
# Name: Quarter, dtype: object

# %%
pivot = df_D01.pivot_table(index=['Return type group', 'Return type',], columns=['Quarter'])

# %%
pivot
# Out:
#                                                                                   Number of returns  \
# Quarter                                                                                     2004 Q1
# Return type group                               Return type
# Enforced return                                 Enforced removals                          7.908163
#                                                 Enforced removals from detention                NaN
#                                                 Non-detained Enforced removals                  NaN
#                                                 Non-detained enforced removals                  NaN
#                                                 Other returns from detention                    NaN
# Refused entry at port and subsequently departed Departed from Juxtaposed controls               NaN
#                                                 Departed from UK Ports                          NaN
# ...

# %%
df_Ret = pd.read_excel (r'returns-datasets-sep-2020.xlsx', sheet_name='Ret_D01', skiprows = 8)

# %%
df_Ret
# Out:
#                                          Row Labels  2010 Q1  2010 Q2  \
# 0                                   Enforced return     3568     3236
# 1                  Enforced removals from detention     3011     2794
# 2                    Non-detained Enforced removals      244      130
# 3                      Other returns from detention      313      312
# 4   Refused entry at port and subsequently departed     4952     4575
# 5                 Departed from Juxtaposed controls     1403     1500
# 6                            Departed from UK Ports     3549     3075
# 7                                  Voluntary return     8350     7977
# 8                                  Assisted returns     1205      866
# 9                                Controlled returns     2035     2062
# 10                           Other verified returns     5110     5049
# 11                                      Grand Total    16870    15788
#
# ...

# %%
df_Ret.columns
# Out:
# Index(['Row Labels', '2010 Q1', '2010 Q2', '2010 Q3', '2010 Q4', '2011 Q1',
#        '2011 Q2', '2011 Q3', '2011 Q4', '2012 Q1', '2012 Q2', '2012 Q3',
#        '2012 Q4', '2013 Q1', '2013 Q2', '2013 Q3', '2013 Q4', '2014 Q1',
#        '2014 Q2', '2014 Q3', '2014 Q4', '2015 Q1', '2015 Q2', '2015 Q3',
#        '2015 Q4', '2016 Q1', '2016 Q2', '2016 Q3', '2016 Q4', '2017 Q1',
#        '2017 Q2', '2017 Q3', '2017 Q4', '2018 Q1', '2018 Q2', '2018 Q3',
#        '2018 Q4', '2019 Q1', '2019 Q2', '2019 Q3', '2019 Q4', '2020 Q1',
#        '2020 Q2', 'Grand Total'],
#       dtype='object')
